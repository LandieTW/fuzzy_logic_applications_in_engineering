# %% [markdown]
# # Intuition

# %% [markdown]
# # Inference

# %% [markdown]
# # Rank ordering

# %% [markdown]
# # Neural networks

# %% [markdown]
# # Genetic algorithms

# %% [markdown]
# # Inductive reasoning
